# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("speech.txt")
text_documents = loader.load()

text_documents
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_30892\2772868744.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ...

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("speech.txt")
text_documents = loader.load()

text_documents
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The Unfinished Symphony of FreedomFriends, citizens, and fellow travelers in this grand experiment,We gather today not just to celebrate a system of government, but to renew a promise.Democracy is not a silent monument carved from cold marble. It is not a static document locked away in a glass case, nor is it a prize won once and possessed forever. Democracy is a living, breathing, and often fragile idea. It is the radical belief that a nationâ€™s destiny belongs not to the few with power, wealth, or pedigree, but to the collective wisdom of its people\nLook back through the long, winding corridor of human history. For centuries, the story of humanity was written by kings, emperors, and tyrants. Their word was law, and the people were merely footnotes. But then came a revolutionary sparkâ€”the audacious idea that legitimate power flows from the bottom up, not from the top down. That the ballot is mightier than the sword. That
# ...

# %%
import os
from dotenv import load_dotenv

load_dotenv("../.env")

gemini_api_key = os.getenv("GEMINI_API_KEY")
if gemini_api_key:
	os.environ["GEMINI_API_KEY"] = gemini_api_key

# %%
##web based loader
import os
os.environ["USER_AGENT"] = "Mozilla/5.0"

from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
    web_paths=[
        "https://www.oreilly.com/library/view/learning-python-5th/9781449355722/ch01.html"
    ],
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-title", "post-content", "post-header")
        )
    )
)

docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://www.oreilly.com/library/view/learning-python-5th/9781449355722/ch01.html'}, page_content='')]

# %%
docs
# Out:
# [Document(metadata={'source': 'https://www.oreilly.com/library/view/learning-python-5th/9781449355722/ch01.html'}, page_content='')]

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Naresh_resume.pdf")
docs = loader.load()

docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-06-11T15:09:49+05:30', 'author': 'Muthyala Omkiran', 'moddate': '2026-06-11T15:09:49+05:30', 'source': 'Naresh_resume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='NARESH KUKKALA \nHYDERABAD | Telangana | INDIA \nGmail: nareshkukkala633@gmail.com | Phone Number: 9392391663 | LinkedIn: linkedin.com/in/naresh-kukkala-0b7a1b302 \nPROFESSIONAL SUMMARY: \nVLSI Design and Verification Engineer with hands-on experience in RTL Design and Functional Verification using \nVerilog, system Verilog, and UVM.  Skilled in AMBA-APB and Ethernet protocol verification, testbench development,  \nfunctional coverage, assertions, and debugging using QuestaSim. Passionate about delivering high-quality verification \nsolutions. \nSKILLS: \nTechnical skills: Verilog, System Verilog, UVM, PERL, C, Python, Oops. \nVerification: Assertions(SVA), Functional Coverage, RAL, Self-c
# ...

# %%
# %pip  install langchain_text_splitter
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement langchain_text_splitter (from versions: none)
# ERROR: No matching distribution found for langchain_text_splitter

# %%
# %pip install -U langchain-text-splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitter import RecursiveCharacterTextSplitter      
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(docs)
documents[:5]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_text_splitter import RecursiveCharacterTextSplitter
#       2 text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
#       3 documents = text_splitter.split_documents(docs)
#       4 documents[:5]
#
# ModuleNotFoundError: No module named 'langchain_text_splitter'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\mahen\OneDrive\Desktop\Langchain\venv\Scripts\python.exe

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Ollama
db=Chroma.from_documents(documents[:20], embedding=OllamaEmbeddings(model="llama2-7b"))
